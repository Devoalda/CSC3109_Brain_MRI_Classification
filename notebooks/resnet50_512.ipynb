# %%
import os

import keras

print("Keras = {}".format(keras.__version__))
import tensorflow as tf

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
import seaborn as sns
import pandas as pd


# Print gpus
gpus = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(gpus))

# model_dir = './models/'
model_file = 'resnet50_brain_mri.keras'
# Out:
# Keras = 2.15.0
# Num GPUs Available:  1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! unzip -o /content/drive/MyDrive/dataset_19.zip
# ! unzip -o /content/drive/MyDrive/Brain_MRI.zip

! pwd
# Out:
# Archive:  /content/drive/MyDrive/dataset_19.zip
#   inflating: dataset_19/glioma/Te-gl_0010.jpg
#   inflating: dataset_19/glioma/Te-gl_0016.jpg
#   inflating: dataset_19/glioma/Te-gl_0020.jpg
#   inflating: dataset_19/glioma/Te-gl_0026.jpg
#   inflating: dataset_19/glioma/Te-gl_0035.jpg
#   inflating: dataset_19/glioma/Te-gl_0041.jpg
#   inflating: dataset_19/glioma/Te-gl_0043.jpg
#   inflating: dataset_19/glioma/Te-gl_0044.jpg
#   inflating: dataset_19/glioma/Te-gl_0045.jpg
#   inflating: dataset_19/glioma/Te-gl_0057.jpg
#   inflating: dataset_19/glioma/Te-gl_0060.jpg
#   inflating: dataset_19/glioma/Te-gl_0075.jpg
#   inflating: dataset_19/glioma/Te-gl_0079.jpg
#   inflating: dataset_19/glioma/Te-gl_0085.jpg
#   inflating: dataset_19/glioma/Te-gl_0090.jpg
#   inflating: dataset_19/glioma/Te-gl_0107.jpg
#   inflating: dataset_19/glioma/Te-gl_0114.jpg
#   inflating: dataset_19/glioma/Te-gl_0125.jpg
#   inflating: dataset_19/glioma/Te-gl_0126.jpg
#   inflating: dataset_19/glioma/Te-gl_0127.jpg
#   inflating: dataset_19/glioma/Te-gl_0136.jpg
#   inflating: dataset_19/glioma/Te-gl_0144.jpg
#   inflating: dataset_19/glioma/Te-gl_0154.jpg
#   inflating: dataset_19/glioma/Te-gl_0155.jpg
#   inflating: dataset_19/glioma/Te-gl_0162.jpg
#   inflating: dataset_19/glioma/Te-gl_0166.jpg
#   inflating: dataset_19/glioma/Te-gl_0167.jpg
#   inflating: dataset_19/glioma/Te-gl_0168.jpg
#   inflating: dataset_19/glioma/Te-gl_0172.jpg
#   inflating: dataset_19/glioma/Te-gl_0183.jpg
#   inflating: dataset_19/glioma/Te-gl_0192.jpg
#   inflating: dataset_19/glioma/Te-gl_0195.jpg
#   inflating: dataset_19/glioma/Te-gl_0199.jpg
#   inflating: dataset_19/glioma/Tr-gl_0016.jpg
#   inflating: dataset_19/glioma/Tr-gl_0026.jpg
#   inflating: dataset_19/glioma/Tr-gl_0031.jpg
#   inflating: dataset_19/glioma/Tr-gl_0039.jpg
#   inflating: dataset_19/glioma/Tr-gl_0049.jpg
#   inflating: dataset_19/glioma/Tr-gl_0052.jpg
#   inflating: dataset_19/glioma/Tr-gl_0054.jpg
#   inflating: dataset_19/glioma/Tr-gl_0062.jpg
#   inflating: dataset_19/glioma/Tr-gl_0072.jpg
#   inflating: dataset_19/glioma/Tr-gl_0078.jpg
#   inflating: dataset_19/glioma/Tr-gl_0084.jpg
jpg
#   inflating: dataset_19/pituitary/Tr-pi_0507.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0509.jpg
# /content

# %% [markdown]
# # Load the data

# %%
# Data Directories
dir = "dataset_19/"
# validation_dir = "Testing"

# %% [markdown]
# # Data distribution

# %%
data_distribution_count = pd.Series(
    {curr_index: len(os.listdir(os.path.join(dir, curr_index))) for curr_index in os.listdir(dir)})

data_distribution_count
# Out:
# pituitary     120
# glioma        120
# meningioma    120
# notumor       120
# dtype: int64

# %%
fig, axis = plt.subplots(figsize=(13, 5))
axis.grid(True, alpha=0.1)
axis.set_title("Data Distribution Percentage (%)", fontsize=14)
sns.barplot(x=['\n'.join(curr_index.strip().split('_')).title() for curr_index in data_distribution_count.index],
            y=100 * data_distribution_count / data_distribution_count.sum(), ax=axis)
axis.set_xlabel("Tumor Class", fontsize=12)
axis.set_ylabel("% Total Observations", fontsize=12)
axis.tick_params(which='major', labelsize=12)
axis.text(2.5, 37, f'Total Observations: {data_distribution_count.sum()}', fontdict=dict(size=12))
sns.despine()

# %% [markdown]
# # Preprocess Data

# %%
# from tqdm import tqdm
# import cv2
# import imutils

# def crop_img(img):

# 	# Find extreme points on the image and crop the rectangular out

# 	gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
# 	gray = cv2.GaussianBlur(gray, (3, 3), 0)

# 	# threshold the image, then perform a series of erosions +
# 	# dilations to remove any small regions of noise
# 	thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
# 	thresh = cv2.erode(thresh, None, iterations=2)
# 	thresh = cv2.dilate(thresh, None, iterations=2)

# 	# find contours in thresholded image, then grab the largest one
# 	cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# 	cnts = imutils.grab_contours(cnts)
# 	c = max(cnts, key=cv2.contourArea)

# 	# find the extreme points
# 	extLeft = tuple(c[c[:, :, 0].argmin()][0])
# 	extRight = tuple(c[c[:, :, 0].argmax()][0])
# 	extTop = tuple(c[c[:, :, 1].argmin()][0])
# 	extBot = tuple(c[c[:, :, 1].argmax()][0])
# 	ADD_PIXELS = 0
# 	new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

# 	return new_img

# def preprocess_images(directory):
#     for dir in os.listdir(directory):
#         path = os.path.join(directory, dir)
#         for img_name in os.listdir(path):
#             img_path = os.path.join(path, img_name)
#             img = cv2.imread(img_path)
#             cropped_img = crop_img(img)
#             cv2.imwrite(img_path, cropped_img)

# # Preprocess the images before generating data
# preprocess_images(dir)
# # preprocess_images(validation_dir)

# %% [markdown]
# # Split data

# %%
classes = os.listdir(dir)

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    horizontal_flip=True,
    validation_split=0.2)

validation_datagen = ImageDataGenerator(rescale=1. / 255,
                                        validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    dir,
    target_size=(512, 512),
    batch_size=16,
    seed=42,
    subset='training'
)

test_generator = validation_datagen.flow_from_directory(
    dir,
    target_size=(512, 512),
    batch_size=16,
    seed=42,
    subset='validation')


print(test_generator.class_indices)

# Get the number of samples in the training and testing data
num_train_samples = train_generator.samples
num_test_samples = test_generator.samples

# Get the distribution of classes in the training and testing data
train_class_distribution = np.bincount(train_generator.classes)
test_class_distribution = np.bincount(test_generator.classes)

# Create a figure with 3 subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the train/test split
axes[0].pie([num_train_samples, num_test_samples], labels=['Train', 'Test'], autopct='%1.1f%%')
axes[0].set_title('Train/Test Split')

# Plot the distribution of classes in the training data
axes[1].pie(train_class_distribution, labels=classes, autopct='%1.1f%%')
axes[1].set_title('Class Distribution in Training Data')

# Plot the distribution of classes in the testing data
axes[2].pie(test_class_distribution, labels=classes, autopct='%1.1f%%')
axes[2].set_title('Class Distribution in Testing Data')

# Display the plots
plt.show()
# Out:
# Found 384 images belonging to 4 classes.
# Found 96 images belonging to 4 classes.
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %% [markdown]
# # Functions to train model

# %%
import os
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, load_model
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.utils import plot_model
from keras.applications import ResNet50
import matplotlib.pyplot as plt

# Define the model creation function
def create_model(input_shape, num_classes):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    for layer in base_model.layers:
      layer.trainable = True
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.4)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Define the model training function
def train_model(model, train_generator, test_generator, model_name):
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    #early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10, verbose=1, mode='auto', restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2,verbose=1, mode='min', min_lr=0.0000000)

    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // train_generator.batch_size,
        validation_data=test_generator,
        validation_steps=test_generator.samples // test_generator.batch_size,
        epochs=50,
        callbacks=[checkpoint, reduce_lr]
    )

    model.save(model_name)
    return model, history

# %% [markdown]
# # Create/Load model

# %%
# Check if the model exists, else create and train it
if os.path.exists(model_file):
    model = load_model(model_file)
else:
    model = create_model((512, 512, 3), len(classes))

# Plot the model architecture
plot_model(model, to_file='resnet50_model.png', show_shapes=True, show_layer_names=True)
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 518, 518, 3)          0         ['input_7[0][0]']
#
#  conv1_conv (Conv2D)         (None, 256, 256, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 256, 256, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 256, 256, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 258, 258, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 128, 128, 64)         0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 128, 128, 64)         4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 128, 128, 256)        16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 128, 128, 256)        0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 128, 128, 256)        0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 128, 128, 64)         16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 128, 128, 256)        0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 128, 128, 256)        0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 128, 128, 64)         16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 128, 128, 64)         36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 128, 128, 64)         256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 128, 128, 64)         0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 128, 128, 256)        16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 128, 128, 256)        1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 128, 128, 256)        0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 128, 128, 256)        0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 64, 64, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 64, 64, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 64, 64, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 64, 64, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 64, 64, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 64, 64, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 64, 64, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 64, 64, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 64, 64, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 64, 64, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 64, 64, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 64, 64, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 64, 64, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 64, 64, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 64, 64, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 64, 64, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 32, 32, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 32, 32, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 32, 32, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 32, 32, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 32, 32, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 32, 32, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 32, 32, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 32, 32, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 32, 32, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 16, 16, 512)          524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 16, 16, 2048)         2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 16, 16, 512)          1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 16, 16, 512)          1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 16, 16, 512)          2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 16, 16, 512)          2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 16, 16, 512)          0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 16, 16, 2048)         1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 16, 16, 2048)         8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 16, 16, 2048)         0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 16, 16, 2048)         0         ['conv5_block3_add[0][0]']
#  on)
#
#  global_average_pooling2d_5  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_6 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  dense_11 (Dense)            (None, 4)                    8196      ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 23595908 (90.01 MB)
# Trainable params: 23542788 (89.81 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
model, history = train_model(model, train_generator, test_generator, model_file)
# Out:
# Epoch 1/50
# 24/24 [==============================] - ETA: 0s - loss: 0.7557 - accuracy: 0.7370
# Epoch 1: val_loss improved from inf to 3.77081, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 57s 1s/step - loss: 0.7557 - accuracy: 0.7370 - val_loss: 3.7708 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 2/50
# 24/24 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.9089
# Epoch 2: val_loss improved from 3.77081 to 3.58109, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 24s 993ms/step - loss: 0.2470 - accuracy: 0.9089 - val_loss: 3.5811 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 3/50
# 24/24 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.9531
# Epoch 3: val_loss did not improve from 3.58109
# 24/24 [==============================] - 22s 916ms/step - loss: 0.1277 - accuracy: 0.9531 - val_loss: 4.4478 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 4/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9896
# Epoch 4: val_loss did not improve from 3.58109
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 24/24 [==============================] - 23s 971ms/step - loss: 0.0513 - accuracy: 0.9896 - val_loss: 4.0971 - val_accuracy: 0.2500 - lr: 1.0000e-04
# Epoch 5/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9922
# Epoch 5: val_loss did not improve from 3.58109
# 24/24 [==============================] - 22s 920ms/step - loss: 0.0366 - accuracy: 0.9922 - val_loss: 4.5226 - val_accuracy: 0.2500 - lr: 3.0000e-05
# Epoch 6/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9974
# Epoch 6: val_loss did not improve from 3.58109
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 24/24 [==============================] - 22s 907ms/step - loss: 0.0169 - accuracy: 0.9974 - val_loss: 4.9690 - val_accuracy: 0.2500 - lr: 3.0000e-05
# Epoch 7/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9974
# Epoch 7: val_loss did not improve from 3.58109
# 24/24 [==============================] - 23s 958ms/step - loss: 0.0138 - accuracy: 0.9974 - val_loss: 4.9824 - val_accuracy: 0.2500 - lr: 9.0000e-06
# Epoch 8/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9948
# Epoch 8: val_loss did not improve from 3.58109
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 24/24 [==============================] - 22s 910ms/step - loss: 0.0186 - accuracy: 0.9948 - val_loss: 4.9717 - val_accuracy: 0.2500 - lr: 9.0000e-06
# Epoch 9/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9974
# Epoch 9: val_loss did not improve from 3.58109
# 24/24 [==============================] - 22s 904ms/step - loss: 0.0183 - accuracy: 0.9974 - val_loss: 5.0667 - val_accuracy: 0.2500 - lr: 2.7000e-06
# Epoch 10/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 10: val_loss did not improve from 3.58109
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# 24/24 [==============================] - 22s 917ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 5.2259 - val_accuracy: 0.2500 - lr: 2.7000e-06
# Epoch 11/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 3.58109
# 24/24 [==============================] - 22s 922ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 5.3769 - val_accuracy: 0.2500 - lr: 8.1000e-07
# Epoch 12/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9974
# Epoch 12: val_loss did not improve from 3.58109
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# 24/24 [==============================] - 22s 932ms/step - loss: 0.0130 - accuracy: 0.9974 - val_loss: 5.4844 - val_accuracy: 0.2500 - lr: 8.1000e-07
# Epoch 13/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9948
# Epoch 13: val_loss did not improve from 3.58109
# 24/24 [==============================] - 23s 946ms/step - loss: 0.0140 - accuracy: 0.9948 - val_loss: 5.5461 - val_accuracy: 0.2500 - lr: 2.4300e-07
# Epoch 14/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9948
# Epoch 14: val_loss did not improve from 3.58109
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 7.289999643944612e-08.
# 24/24 [==============================] - 23s 956ms/step - loss: 0.0128 - accuracy: 0.9948 - val_loss: 5.5442 - val_accuracy: 0.2500 - lr: 2.4300e-07
# Epoch 15/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 3.58109
# 24/24 [==============================] - 22s 915ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 5.5069 - val_accuracy: 0.2500 - lr: 7.2900e-08
# Epoch 16/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 3.58109
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.1869998079182552e-08.
# 24/24 [==============================] - 23s 943ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 5.4210 - val_accuracy: 0.2500 - lr: 7.2900e-08
# Epoch 17/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9974
# Epoch 17: val_loss did not improve from 3.58109
# 24/24 [==============================] - 22s 907ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 5.3167 - val_accuracy: 0.2500 - lr: 2.1870e-08
# Epoch 18/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 3.58109
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.560999210591944e-09.
# 24/24 [==============================] - 22s 906ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 5.1479 - val_accuracy: 0.2500 - lr: 2.1870e-08
# Epoch 19/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9974
# Epoch 19: val_loss did not improve from 3.58109
# 24/24 [==============================] - 24s 988ms/step - loss: 0.0182 - accuracy: 0.9974 - val_loss: 4.9683 - val_accuracy: 0.2500 - lr: 6.5610e-09
# Epoch 20/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9948
# Epoch 20: val_loss did not improve from 3.58109
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.968299789822936e-09.
# 24/24 [==============================] - 22s 909ms/step - loss: 0.0203 - accuracy: 0.9948 - val_loss: 4.7589 - val_accuracy: 0.2500 - lr: 6.5610e-09
# Epoch 21/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9896
# Epoch 21: val_loss did not improve from 3.58109
# 24/24 [==============================] - 23s 951ms/step - loss: 0.0251 - accuracy: 0.9896 - val_loss: 4.5431 - val_accuracy: 0.2500 - lr: 1.9683e-09
# Epoch 22/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9974
# Epoch 22: val_loss did not improve from 3.58109
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.904899236242044e-10.
# 24/24 [==============================] - 22s 913ms/step - loss: 0.0135 - accuracy: 0.9974 - val_loss: 4.3231 - val_accuracy: 0.2500 - lr: 1.9683e-09
# Epoch 23/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9948
# Epoch 23: val_loss did not improve from 3.58109
# 24/24 [==============================] - 22s 898ms/step - loss: 0.0136 - accuracy: 0.9948 - val_loss: 4.0980 - val_accuracy: 0.2500 - lr: 5.9049e-10
# Epoch 24/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9922
# Epoch 24: val_loss did not improve from 3.58109
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.771469804179304e-10.
# 24/24 [==============================] - 24s 986ms/step - loss: 0.0220 - accuracy: 0.9922 - val_loss: 3.8972 - val_accuracy: 0.2500 - lr: 5.9049e-10
# Epoch 25/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 3.58109
# 24/24 [==============================] - 22s 922ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 3.6815 - val_accuracy: 0.2500 - lr: 1.7715e-10
# Epoch 26/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9974
# Epoch 26: val_loss improved from 3.58109 to 3.46076, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 26s 1s/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 3.4608 - val_accuracy: 0.2500 - lr: 1.7715e-10
# Epoch 27/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 27: val_loss improved from 3.46076 to 3.24258, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 24s 1s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 3.2426 - val_accuracy: 0.2604 - lr: 1.7715e-10
# Epoch 28/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9974
# Epoch 28: val_loss improved from 3.24258 to 3.03209, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 30s 1s/step - loss: 0.0129 - accuracy: 0.9974 - val_loss: 3.0321 - val_accuracy: 0.2604 - lr: 1.7715e-10
# Epoch 29/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9974
# Epoch 29: val_loss improved from 3.03209 to 2.83834, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 24s 1s/step - loss: 0.0158 - accuracy: 0.9974 - val_loss: 2.8383 - val_accuracy: 0.2812 - lr: 1.7715e-10
# Epoch 30/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9948
# Epoch 30: val_loss improved from 2.83834 to 2.65608, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 34s 1s/step - loss: 0.0267 - accuracy: 0.9948 - val_loss: 2.6561 - val_accuracy: 0.2917 - lr: 1.7715e-10
# Epoch 31/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 31: val_loss improved from 2.65608 to 2.47327, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 34s 1s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 2.4733 - val_accuracy: 0.3229 - lr: 1.7715e-10
# Epoch 32/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 32: val_loss improved from 2.47327 to 2.28627, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 32s 1s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 2.2863 - val_accuracy: 0.3333 - lr: 1.7715e-10
# Epoch 33/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 33: val_loss improved from 2.28627 to 2.12009, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 26s 1s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 2.1201 - val_accuracy: 0.3542 - lr: 1.7715e-10
# Epoch 34/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9974
# Epoch 34: val_loss improved from 2.12009 to 1.96168, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 25s 1s/step - loss: 0.0138 - accuracy: 0.9974 - val_loss: 1.9617 - val_accuracy: 0.3646 - lr: 1.7715e-10
# Epoch 35/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 35: val_loss improved from 1.96168 to 1.80424, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 25s 1s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.8042 - val_accuracy: 0.4167 - lr: 1.7715e-10
# Epoch 36/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 36: val_loss improved from 1.80424 to 1.67473, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 27s 1s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.6747 - val_accuracy: 0.4375 - lr: 1.7715e-10
# Epoch 37/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 37: val_loss improved from 1.67473 to 1.55305, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 24s 1s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 1.5531 - val_accuracy: 0.4479 - lr: 1.7715e-10
# Epoch 38/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 1.0000
# Epoch 38: val_loss improved from 1.55305 to 1.43852, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 27s 1s/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.4385 - val_accuracy: 0.5208 - lr: 1.7715e-10
# Epoch 39/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9974
# Epoch 39: val_loss improved from 1.43852 to 1.33691, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 24s 999ms/step - loss: 0.0125 - accuracy: 0.9974 - val_loss: 1.3369 - val_accuracy: 0.5312 - lr: 1.7715e-10
# Epoch 40/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9974
# Epoch 40: val_loss improved from 1.33691 to 1.26477, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 25s 1s/step - loss: 0.0133 - accuracy: 0.9974 - val_loss: 1.2648 - val_accuracy: 0.5625 - lr: 1.7715e-10
# Epoch 41/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9974
# Epoch 41: val_loss improved from 1.26477 to 1.20839, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 24s 1s/step - loss: 0.0160 - accuracy: 0.9974 - val_loss: 1.2084 - val_accuracy: 0.5938 - lr: 1.7715e-10
# Epoch 42/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9974
# Epoch 42: val_loss improved from 1.20839 to 1.16107, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 34s 1s/step - loss: 0.0138 - accuracy: 0.9974 - val_loss: 1.1611 - val_accuracy: 0.6146 - lr: 1.7715e-10
# Epoch 43/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9974
# Epoch 43: val_loss improved from 1.16107 to 1.10345, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 24s 1s/step - loss: 0.0149 - accuracy: 0.9974 - val_loss: 1.1034 - val_accuracy: 0.6250 - lr: 1.7715e-10
# Epoch 44/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 44: val_loss improved from 1.10345 to 1.05168, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 24s 1s/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 1.0517 - val_accuracy: 0.6354 - lr: 1.7715e-10
# Epoch 45/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9974
# Epoch 45: val_loss improved from 1.05168 to 1.01250, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 25s 1s/step - loss: 0.0141 - accuracy: 0.9974 - val_loss: 1.0125 - val_accuracy: 0.6667 - lr: 1.7715e-10
# Epoch 46/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9974
# Epoch 46: val_loss improved from 1.01250 to 0.98173, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 24s 1s/step - loss: 0.0130 - accuracy: 0.9974 - val_loss: 0.9817 - val_accuracy: 0.6667 - lr: 1.7715e-10
# Epoch 47/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9922
# Epoch 47: val_loss improved from 0.98173 to 0.95878, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 33s 1s/step - loss: 0.0281 - accuracy: 0.9922 - val_loss: 0.9588 - val_accuracy: 0.6771 - lr: 1.7715e-10
# Epoch 48/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 1.0000
# Epoch 48: val_loss improved from 0.95878 to 0.94916, saving model to resnet50_brain_mri.keras
# 24/24 [==============================] - 26s 1s/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.9492 - val_accuracy: 0.6667 - lr: 1.7715e-10
# Epoch 49/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9974
# Epoch 49: val_loss did not improve from 0.94916
# 24/24 [==============================] - 22s 912ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.9528 - val_accuracy: 0.6667 - lr: 1.7715e-10
# Epoch 50/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9974
# Epoch 50: val_loss did not improve from 0.94916
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 5.314409329271186e-11.
# 24/24 [==============================] - 23s 945ms/step - loss: 0.0146 - accuracy: 0.9974 - val_loss: 0.9512 - val_accuracy: 0.6771 - lr: 1.7715e-10

# %% [markdown]
# # Testing the model

# %%
# Learning curve
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation','Loss', 'Value Loss'], loc='upper left')
plt.show()

# %%
#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
plt.show()

# %% [markdown]
# # Validate with external test data

# %%
# Validate the model with test data

model = keras.models.load_model(model_file)
model.evaluate(test_generator)

# Predict the output
predictions = model.predict(test_generator)
predictions = np.argmax(predictions, axis=1)

# Predict and Display image using matplotlib
plt.figure(figsize=(20, 20))
for i in range(8):
    plt.subplot(3, 3, i + 1)
    for X_batch, Y_batch in test_generator:
        image = X_batch[0]
        # Print Class
        plt.title("Predicted: " + classes[predictions[i]] + "\nActual: " + classes[np.argmax(Y_batch[i])])

        plt.imshow(image)
        break
# Out:
# 6/6 [==============================] - 4s 274ms/step - loss: 0.9512 - accuracy: 0.6771
# 6/6 [==============================] - 2s 274ms/step

# %% [markdown]
# # Model visualization(Evaluation)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_generator.classes, predictions)
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Values')
plt.ylabel('True Values');

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

def calculate_metrics(y_true, y_pred):
    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Calculate metrics for each class and average them
    dsc = np.mean([2.0 * cm[i, i] / (np.sum(cm[i, :]) + np.sum(cm[:, i])) for i in range(cm.shape[0])])
    sensitivity = np.mean([cm[i, i] / np.sum(cm[i, :]) for i in range(cm.shape[0])])
    specificity = np.mean([np.sum(np.delete(np.delete(cm, j, 0), j, 1)) / np.sum(np.delete(cm, j, 0)) for j in range(cm.shape[0])])
    # Accuracy
    accuracy = accuracy_score(y_true, y_pred)

    return dsc, sensitivity, specificity, accuracy

# Usage:
dsc, sensitivity, specificity, accuracy = calculate_metrics(test_generator.classes, predictions)
print(f"DSC: {dsc}, Sensitivity: {sensitivity}, Specificity: {specificity}, Accuracy: {accuracy}")
# Out:
# DSC: 0.20240084005536726, Sensitivity: 0.22916666666666666, Specificity: 0.7430555555555556, Accuracy: 0.22916666666666666
