# %%
import os

import keras

print("Keras = {}".format(keras.__version__))
import tensorflow as tf

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
import seaborn as sns
import pandas as pd


# Print gpus
gpus = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(gpus))

model_dir = './models/'
model_file = model_dir + 'inception.keras'
# Out:
# Keras = 2.15.0
# Num GPUs Available:  1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip -o drive/MyDrive/dataset_19.zip

! pwd
# Out:
# Archive:  drive/MyDrive/dataset_19.zip
#   inflating: dataset_19/glioma/Te-gl_0010.jpg
#   inflating: dataset_19/glioma/Te-gl_0016.jpg
#   inflating: dataset_19/glioma/Te-gl_0020.jpg
#   inflating: dataset_19/glioma/Te-gl_0026.jpg
#   inflating: dataset_19/glioma/Te-gl_0035.jpg
#   inflating: dataset_19/glioma/Te-gl_0041.jpg
#   inflating: dataset_19/glioma/Te-gl_0043.jpg
#   inflating: dataset_19/glioma/Te-gl_0044.jpg
#   inflating: dataset_19/glioma/Te-gl_0045.jpg
#   inflating: dataset_19/glioma/Te-gl_0057.jpg
#   inflating: dataset_19/glioma/Te-gl_0060.jpg
#   inflating: dataset_19/glioma/Te-gl_0075.jpg
#   inflating: dataset_19/glioma/Te-gl_0079.jpg
#   inflating: dataset_19/glioma/Te-gl_0085.jpg
#   inflating: dataset_19/glioma/Te-gl_0090.jpg
#   inflating: dataset_19/glioma/Te-gl_0107.jpg
#   inflating: dataset_19/glioma/Te-gl_0114.jpg
#   inflating: dataset_19/glioma/Te-gl_0125.jpg
#   inflating: dataset_19/glioma/Te-gl_0126.jpg
#   inflating: dataset_19/glioma/Te-gl_0127.jpg
#   inflating: dataset_19/glioma/Te-gl_0136.jpg
#   inflating: dataset_19/glioma/Te-gl_0144.jpg
#   inflating: dataset_19/glioma/Te-gl_0154.jpg
#   inflating: dataset_19/glioma/Te-gl_0155.jpg
#   inflating: dataset_19/glioma/Te-gl_0162.jpg
#   inflating: dataset_19/glioma/Te-gl_0166.jpg
#   inflating: dataset_19/glioma/Te-gl_0167.jpg
#   inflating: dataset_19/glioma/Te-gl_0168.jpg
#   inflating: dataset_19/glioma/Te-gl_0172.jpg
#   inflating: dataset_19/glioma/Te-gl_0183.jpg
#   inflating: dataset_19/glioma/Te-gl_0192.jpg
#   inflating: dataset_19/glioma/Te-gl_0195.jpg
#   inflating: dataset_19/glioma/Te-gl_0199.jpg
#   inflating: dataset_19/glioma/Tr-gl_0016.jpg
#   inflating: dataset_19/glioma/Tr-gl_0026.jpg
#   inflating: dataset_19/glioma/Tr-gl_0031.jpg
#   inflating: dataset_19/glioma/Tr-gl_0039.jpg
#   inflating: dataset_19/glioma/Tr-gl_0049.jpg
#   inflating: dataset_19/glioma/Tr-gl_0052.jpg
#   inflating: dataset_19/glioma/Tr-gl_0054.jpg
#   inflating: dataset_19/glioma/Tr-gl_0062.jpg
#   inflating: dataset_19/glioma/Tr-gl_0072.jpg
#   inflating: dataset_19/glioma/Tr-gl_0078.jpg
#   inflating: dataset_19/glioma/Tr-gl_0084.jpg
#   inflating: dataset_19/glioma/Tr-gl_0086.jpg
#   inflating: dataset_19/glioma/Tr-gl_0096.jpg
#   inflating: dataset_19/glioma/Tr-gl_0106.jpg
#   inflating: dataset_19/glioma/Tr-gl_0111.jpg
#   inflating: dataset_19/glioma/Tr-gl_0113.jpg
#   inflating: dataset_19/glioma/Tr-gl_0118.jpg
#   inflating: dataset_19/glioma/Tr-gl_0119.jpg
#   inflating: dataset_19/glioma/Tr-gl_0127(1).jpg
#   inflating: dataset_19/glioma/Tr-gl_
#   inflating: dataset_19/pituitary/Te-pi_0103.jpg
#   inflating: dataset_19/pituitary/Te-pi_0108.jpg
#   inflating: dataset_19/pituitary/Te-pi_0116.jpg
#   inflating: dataset_19/pituitary/Te-pi_0123.jpg
#   inflating: dataset_19/pituitary/Te-pi_0132.jpg
#   inflating: dataset_19/pituitary/Te-pi_0144.jpg
#   inflating: dataset_19/pituitary/Te-pi_0146.jpg
#   inflating: dataset_19/pituitary/Te-pi_0148.jpg
#   inflating: dataset_19/pituitary/Te-pi_0153.jpg
#   inflating: dataset_19/pituitary/Te-pi_0160.jpg
#   inflating: dataset_19/pituitary/Te-pi_0162.jpg
#   inflating: dataset_19/pituitary/Te-pi_0171.jpg
#   inflating: dataset_19/pituitary/Te-pi_0174.jpg
#   inflating: dataset_19/pituitary/Te-pi_0182.jpg
#   inflating: dataset_19/pituitary/Te-pi_0202.jpg
#   inflating: dataset_19/pituitary/Te-pi_0204.jpg
#   inflating: dataset_19/pituitary/Te-pi_0206.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0023.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0035.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0037.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0039(3).jpg
#   inflating: dataset_19/pituitary/Tr-pi_0039.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0040.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0045.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0051.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0054.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0067.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0074.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0086.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0091.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0098.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0099.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0105.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0107.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0110.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0118.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0119.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0121.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0122.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0123.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0126.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0132.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0145.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0147.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0149.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0153.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0156.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0159(1).jpg
#   inflating: dataset_19/pituitary/Tr-pi_0159(2).jpg
#   inflating: dataset_19/pituitary/Tr-pi_0162.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0165.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0170.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0171.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0190.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0194.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0199.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0204.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0206.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0213.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0218.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0224.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0229.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0238.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0250.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0260.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0263.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0274.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0282.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0298.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0308.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0311.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0315.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0326.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0327.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0330.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0347.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0356.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0359.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0362.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0367.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0374.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0375.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0388.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0394.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0396.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0399.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0400.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0405.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0420.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0430.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0450.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0451.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0452.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0455.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0462.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0464.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0469.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0472.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0479.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0485.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0486.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0487.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0489.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0494.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0496.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0503.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0507.jpg
#   inflating: dataset_19/pituitary/Tr-pi_0509.jpg
# /content

# %% [markdown]
# # Load the data

# %%
# Data Directories
dir = "dataset_19/"

# %% [markdown]
# ## Data Distribution

# %%
data_distribution_count = pd.Series(
    {curr_index: len(os.listdir(os.path.join(dir, curr_index))) for curr_index in os.listdir(dir)})

data_distribution_count
# Out:
# meningioma    120
# glioma        120
# pituitary     120
# notumor       120
# dtype: int64

# %%
fig, axis = plt.subplots(figsize=(13, 5))
axis.grid(True, alpha=0.1)
axis.set_title("Data Distribution Percentage (%)", fontsize=14)
sns.barplot(x=['\n'.join(curr_index.strip().split('_')).title() for curr_index in data_distribution_count.index],
            y=100 * data_distribution_count / data_distribution_count.sum(), ax=axis)
axis.set_xlabel("Tumor Class", fontsize=12)
axis.set_ylabel("% Total Observations", fontsize=12)
axis.tick_params(which='major', labelsize=12)
axis.text(2.5, 37, f'Total Observations: {data_distribution_count.sum()}', fontdict=dict(size=12))
sns.despine()

# %% [markdown]
# # Preprocess Data

# %%
from tqdm import tqdm
import cv2
import imutils

def crop_img(img):

  # Find extreme points on the image and crop the rectangular out

  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  gray = cv2.GaussianBlur(gray, (3, 3), 0)

  # threshold the image, then perform a series of erosions +
  # dilations to remove any small regions of noise
  thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
  thresh = cv2.erode(thresh, None, iterations=2)
  thresh = cv2.dilate(thresh, None, iterations=2)

  # find contours in thresholded image, then grab the largest one
  cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  cnts = imutils.grab_contours(cnts)
  c = max(cnts, key=cv2.contourArea)

  # find the extreme points
  extLeft = tuple(c[c[:, :, 0].argmin()][0])
  extRight = tuple(c[c[:, :, 0].argmax()][0])
  extTop = tuple(c[c[:, :, 1].argmin()][0])
  extBot = tuple(c[c[:, :, 1].argmax()][0])
  ADD_PIXELS = 0
  new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

  return new_img

def preprocess_images(directory):
    for dir in os.listdir(directory):
        path = os.path.join(directory, dir)
        for img_name in os.listdir(path):
            img_path = os.path.join(path, img_name)
            img = cv2.imread(img_path)
            cropped_img = crop_img(img)
            processed_img = cv2.cvtColor(cropped_img, cv2.COLOR_RGB2GRAY)
            processed_img = cv2.bilateralFilter(processed_img, 2, 50, 50)
            processed_img = cv2.applyColorMap(processed_img, cv2.COLORMAP_BONE)
            processed_img = cv2.resize(processed_img, (224, 224))
            cv2.imwrite(img_path, processed_img)


# Preprocess the images before generating data
preprocess_images(dir)

# Display 9 image using matplotlib
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    for curr_index in os.listdir(dir):
        path = os.path.join(dir, curr_index)
        for img_name in os.listdir(path):
            img_path = os.path.join(path, img_name)
            image = plt.imread(img_path)
            plt.imshow(image)
            plt.title(curr_index)
            break
        break

# %% [markdown]
# ## Splitting the data

# %%
classes = os.listdir(dir)

batch_size = 10

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.05,
    height_shift_range=0.05,
    validation_split=0.2)

validation_datagen = ImageDataGenerator(rescale=1. / 255,
                                        validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    dir,
    target_size=(224, 224),
    batch_size=batch_size,
    seed=42,
    subset='training'
)

test_generator = validation_datagen.flow_from_directory(
    dir,
    target_size=(224, 224),
    batch_size=batch_size,
    seed=42,
    shuffle = False,
    subset='validation')


print(test_generator.class_indices)
# Out:
# Found 384 images belonging to 4 classes.
# Found 96 images belonging to 4 classes.
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %% [markdown]
# # Model Training

# %%
# !pip install tensorflow-addons optuna
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)

# %%
from keras.applications import InceptionV3
from tensorflow_addons.optimizers import RectifiedAdam
from keras.models import Model
from keras.layers import GlobalAveragePooling2D, Dense, Dropout
from keras.regularizers import l2
import tensorflow as tf

# Load the InceptionV3 model, include the top layers
base_model = InceptionV3(weights='imagenet', include_top=False,input_shape=(224,224,3))

# Exclude the bottom three layers (remove last 3 layers)
base_model_layers = base_model.layers[:-3]

# Create a new model with the remaining layers
x = base_model_layers[-1].output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.055)(x)

# Final dense layer with 4 neurons for classification
predictions = Dense(4, activation='softmax', kernel_regularizer=l2(0.1), dtype='float64')(x)

# Construct the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model with RectifiedAdam optimizer
optimizer = RectifiedAdam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'categorical_accuracy'])


# Summary of the model
model.summary()
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_94 (Conv2D)          (None, 111, 111, 32)         864       ['input_2[0][0]']
#
#  batch_normalization_94 (Ba  (None, 111, 111, 32)         96        ['conv2d_94[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 111, 111, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 109, 109, 32)         9216      ['activation_94[0][0]']
#
#  batch_normalization_95 (Ba  (None, 109, 109, 32)         96        ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 109, 109, 32)         0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_96 (Conv2D)          (None, 109, 109, 64)         18432     ['activation_95[0][0]']
#
#  batch_normalization_96 (Ba  (None, 109, 109, 64)         192       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 109, 109, 64)         0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 54, 54, 64)           0         ['activation_96[0][0]']
#  g2D)
#
#  conv2d_97 (Conv2D)          (None, 54, 54, 80)           5120      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (Ba  (None, 54, 54, 80)           240       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 54, 54, 80)           0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 52, 52, 192)          138240    ['activation_97[0][0]']
#
#  batch_normalization_98 (Ba  (None, 52, 52, 192)          576       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 52, 52, 192)          0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 25, 25, 192)          0         ['activation_98[0][0]']
#  g2D)
#
#  conv2d_102 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (B  (None, 25, 25, 64)           192       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  activation_102 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  conv2d_100 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_102[0][0]']
#
#  batch_normalization_100 (B  (None, 25, 25, 48)           144       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  batch_normalization_103 (B  (None, 25, 25, 96)           288       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  activation_103 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  average_pooling2d_9 (Avera  (None, 25, 25, 192)          0         ['max_pooling2d_5[0][0]']
#  gePooling2D)
#
#  conv2d_99 (Conv2D)          (None, 25, 25, 64)           12288     ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_100[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 25, 25, 32)           6144      ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (Ba  (None, 25, 25, 64)           192       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 25, 25, 64)           192       ['conv2d_101[0][0]']
#  atchNormalization)
#
#  batch_normalization_104 (B  (None, 25, 25, 96)           288       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 25, 25, 32)           96        ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  activation_101 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  activation_104 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  activation_105 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_99[0][0]',
#                                                                      'activation_101[0][0]',
#                                                                      'activation_104[0][0]',
#                                                                      'activation_105[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_109 (B  (None, 25, 25, 64)           192       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  conv2d_107 (Conv2D)         (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_109[0][0]']
#
#  batch_normalization_107 (B  (None, 25, 25, 48)           144       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 25, 25, 96)           288       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  activation_110 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  average_pooling2d_10 (Aver  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_106 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_107[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_110[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 25, 25, 64)           16384     ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (B  (None, 25, 25, 64)           192       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 25, 25, 64)           192       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 25, 25, 96)           288       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  batch_normalization_112 (B  (None, 25, 25, 64)           192       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  activation_108 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  activation_111 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  activation_112 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_106[0][0]',
#                                                                      'activation_108[0][0]',
#                                                                      'activation_111[0][0]',
#                                                                      'activation_112[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_116 (B  (None, 25, 25, 64)           192       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  activation_116 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  conv2d_114 (Conv2D)         (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_116[0][0]']
#
#  batch_normalization_114 (B  (None, 25, 25, 48)           144       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 25, 25, 96)           288       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  activation_114 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  activation_117 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  average_pooling2d_11 (Aver  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_113 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_114[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_117[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 25, 25, 64)           18432     ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (B  (None, 25, 25, 64)           192       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  batch_normalization_115 (B  (None, 25, 25, 64)           192       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 25, 25, 96)           288       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 25, 25, 64)           192       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  activation_113 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  activation_115 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  activation_118 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_118[0][0
#  )                                                                  ]']
#
#  activation_119 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_119[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_113[0][0]',
#                                                                      'activation_115[0][0]',
#                                                                      'activation_118[0][0]',
#                                                                      'activation_119[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_121 (B  (None, 25, 25, 64)           192       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  activation_121 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  conv2d_122 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_121[0][0]']
#
#  batch_normalization_122 (B  (None, 25, 25, 96)           288       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  activation_122 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  conv2d_120 (Conv2D)         (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_123 (Conv2D)         (None, 12, 12, 96)           82944     ['activation_122[0][0]']
#
#  batch_normalization_120 (B  (None, 12, 12, 384)          1152      ['conv2d_120[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 12, 12, 96)           288       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  activation_120 (Activation  (None, 12, 12, 384)          0         ['batch_normalization_120[0][0
#  )                                                                  ]']
#
#  activation_123 (Activation  (None, 12, 12, 96)           0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_120[0][0]',
#                                                                      'activation_123[0][0]',
#                                                                      'max_pooling2d_6[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_128 (B  (None, 12, 12, 128)          384       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  activation_128 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_128[0][0
#  )                                                                  ]']
#
#  conv2d_129 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_128[0][0]']
#
#  batch_normalization_129 (B  (None, 12, 12, 128)          384       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  activation_129 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_129[0][0
#  )                                                                  ]']
#
#  conv2d_125 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_129[0][0]']
#
#  batch_normalization_125 (B  (None, 12, 12, 128)          384       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  batch_normalization_130 (B  (None, 12, 12, 128)          384       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  activation_125 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_125[0][0
#  )                                                                  ]']
#
#  activation_130 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  conv2d_126 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_125[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_130[0][0]']
#
#  batch_normalization_126 (B  (None, 12, 12, 128)          384       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  batch_normalization_131 (B  (None, 12, 12, 128)          384       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_126 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_126[0][0
#  )                                                                  ]']
#
#  activation_131 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  average_pooling2d_12 (Aver  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_124 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_126[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_131[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (B  (None, 12, 12, 192)          576       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  batch_normalization_127 (B  (None, 12, 12, 192)          576       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  batch_normalization_132 (B  (None, 12, 12, 192)          576       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  batch_normalization_133 (B  (None, 12, 12, 192)          576       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  activation_124 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  activation_127 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_127[0][0
#  )                                                                  ]']
#
#  activation_132 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  activation_133 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_124[0][0]',
#                                                                      'activation_127[0][0]',
#                                                                      'activation_132[0][0]',
#                                                                      'activation_133[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_138 (B  (None, 12, 12, 160)          480       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  activation_138 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  conv2d_139 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_138[0][0]']
#
#  batch_normalization_139 (B  (None, 12, 12, 160)          480       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_135 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_139[0][0]']
#
#  batch_normalization_135 (B  (None, 12, 12, 160)          480       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_140 (B  (None, 12, 12, 160)          480       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  activation_135 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  activation_140 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_136 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_135[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_140[0][0]']
#
#  batch_normalization_136 (B  (None, 12, 12, 160)          480       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  batch_normalization_141 (B  (None, 12, 12, 160)          480       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  activation_136 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  activation_141 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  average_pooling2d_13 (Aver  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_134 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_137 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_136[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_141[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (B  (None, 12, 12, 192)          576       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  batch_normalization_137 (B  (None, 12, 12, 192)          576       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_142 (B  (None, 12, 12, 192)          576       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  batch_normalization_143 (B  (None, 12, 12, 192)          576       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  activation_134 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  activation_137 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  activation_142 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  activation_143 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_134[0][0]',
#                                                                      'activation_137[0][0]',
#                                                                      'activation_142[0][0]',
#                                                                      'activation_143[0][0]']
#
#  conv2d_148 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_148 (B  (None, 12, 12, 160)          480       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  activation_148 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_149 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_148[0][0]']
#
#  batch_normalization_149 (B  (None, 12, 12, 160)          480       ['conv2d_149[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  conv2d_145 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_149[0][0]']
#
#  batch_normalization_145 (B  (None, 12, 12, 160)          480       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_150 (B  (None, 12, 12, 160)          480       ['conv2d_150[0][0]']
#  atchNormalization)
#
# ...
#  conv2d_168 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_167[0][0]']
#
#  batch_normalization_164 (B  (None, 12, 12, 192)          576       ['conv2d_164[0][0]']
#  atchNormalization)
#
#  batch_normalization_168 (B  (None, 12, 12, 192)          576       ['conv2d_168[0][0]']
#  atchNormalization)
#
#  activation_164 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_164[0][0
#  )                                                                  ]']
#
#  activation_168 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_168[0][0
#  )                                                                  ]']
#
#  conv2d_165 (Conv2D)         (None, 5, 5, 320)            552960    ['activation_164[0][0]']
#
#  conv2d_169 (Conv2D)         (None, 5, 5, 192)            331776    ['activation_168[0][0]']
#
#  batch_normalization_165 (B  (None, 5, 5, 320)            960       ['conv2d_165[0][0]']
#  atchNormalization)
#
#  batch_normalization_169 (B  (None, 5, 5, 192)            576       ['conv2d_169[0][0]']
#  atchNormalization)
#
#  activation_165 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_165[0][0
#  )                                                                  ]']
#
#  activation_169 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_169[0][0
#  )                                                                  ]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 5, 5, 768)            0         ['mixed7[0][0]']
#  g2D)
#
#  mixed8 (Concatenate)        (None, 5, 5, 1280)           0         ['activation_165[0][0]',
#                                                                      'activation_169[0][0]',
#                                                                      'max_pooling2d_7[0][0]']
#
#  conv2d_174 (Conv2D)         (None, 5, 5, 448)            573440    ['mixed8[0][0]']
#
#  batch_normalization_174 (B  (None, 5, 5, 448)            1344      ['conv2d_174[0][0]']
#  atchNormalization)
#
#  activation_174 (Activation  (None, 5, 5, 448)            0         ['batch_normalization_174[0][0
#  )                                                                  ]']
#
#  conv2d_171 (Conv2D)         (None, 5, 5, 384)            491520    ['mixed8[0][0]']
#
#  conv2d_175 (Conv2D)         (None, 5, 5, 384)            1548288   ['activation_174[0][0]']
#
#  batch_normalization_171 (B  (None, 5, 5, 384)            1152      ['conv2d_171[0][0]']
#  atchNormalization)
#
#  batch_normalization_175 (B  (None, 5, 5, 384)            1152      ['conv2d_175[0][0]']
#  atchNormalization)
#
#  activation_171 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_171[0][0
#  )                                                                  ]']
#
#  activation_175 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_175[0][0
#  )                                                                  ]']
#
#  conv2d_172 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_173 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_175[0][0]']
#
#  conv2d_177 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_175[0][0]']
#
#  average_pooling2d_16 (Aver  (None, 5, 5, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_170 (Conv2D)         (None, 5, 5, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_172 (B  (None, 5, 5, 384)            1152      ['conv2d_172[0][0]']
#  atchNormalization)
#
#  batch_normalization_173 (B  (None, 5, 5, 384)            1152      ['conv2d_173[0][0]']
#  atchNormalization)
#
#  batch_normalization_176 (B  (None, 5, 5, 384)            1152      ['conv2d_176[0][0]']
#  atchNormalization)
#
#  batch_normalization_177 (B  (None, 5, 5, 384)            1152      ['conv2d_177[0][0]']
#  atchNormalization)
#
#  conv2d_178 (Conv2D)         (None, 5, 5, 192)            245760    ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (B  (None, 5, 5, 320)            960       ['conv2d_170[0][0]']
#  atchNormalization)
#
#  activation_172 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_172[0][0
#  )                                                                  ]']
#
#  activation_173 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_173[0][0
#  )                                                                  ]']
#
#  activation_176 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_176[0][0
#  )                                                                  ]']
#
#  activation_177 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_177[0][0
#  )                                                                  ]']
#
#  batch_normalization_178 (B  (None, 5, 5, 192)            576       ['conv2d_178[0][0]']
#  atchNormalization)
#
#  activation_170 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_170[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 5, 5, 768)            0         ['activation_172[0][0]',
#                                                                      'activation_173[0][0]']
#
#  concatenate_2 (Concatenate  (None, 5, 5, 768)            0         ['activation_176[0][0]',
#  )                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_178[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 5, 5, 2048)           0         ['activation_170[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'activation_178[0][0]']
#
#  conv2d_180 (Conv2D)         (None, 5, 5, 384)            786432    ['mixed9[0][0]']
#
#  batch_normalization_180 (B  (None, 5, 5, 384)            1152      ['conv2d_180[0][0]']
#  atchNormalization)
#
#  activation_180 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_180[0][0
#  )                                                                  ]']
#
#  conv2d_181 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_180[0][0]']
#
#  conv2d_182 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_180[0][0]']
#
#  batch_normalization_181 (B  (None, 5, 5, 384)            1152      ['conv2d_181[0][0]']
#  atchNormalization)
#
#  batch_normalization_182 (B  (None, 5, 5, 384)            1152      ['conv2d_182[0][0]']
#  atchNormalization)
#
#  activation_181 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_181[0][0
#  )                                                                  ]']
#
#  activation_182 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_182[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 5, 5, 768)            0         ['activation_181[0][0]',
#                                                                      'activation_182[0][0]']
#
#  global_average_pooling2d_1  (None, 768)                  0         ['mixed9_1[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 768)                  0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_1 (Dense)             (None, 4)                    3076      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 17400420 (66.39 MB)
# Trainable params: 17370212 (66.27 MB)
# Non-trainable params: 30208 (118.00 KB)
# __________________________________________________________________________________________________

# %%
from keras.callbacks import *

reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=10, factor=0.3, min_lr=1e-6)
checkpoint = ModelCheckpoint(model_file, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=1, mode='auto')

# Fit the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=100,
    validation_data=test_generator,
    validation_steps=test_generator.samples // test_generator.batch_size,
    callbacks=[checkpoint, early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 2.1755 - accuracy: 0.2968 - precision_1: 0.5000 - recall_1: 0.0080 - categorical_accuracy: 0.2968
# Epoch 1: val_loss improved from inf to 2.25438, saving model to ./models/inception.keras
# 38/38 [==============================] - 35s 334ms/step - loss: 2.1755 - accuracy: 0.2968 - precision_1: 0.5000 - recall_1: 0.0080 - categorical_accuracy: 0.2968 - val_loss: 2.2544 - val_accuracy: 0.2667 - val_precision_1: 0.2917 - val_recall_1: 0.0778 - val_categorical_accuracy: 0.2667 - lr: 1.0000e-04
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 2.0383 - accuracy: 0.4492 - precision_1: 0.7826 - recall_1: 0.0481 - categorical_accuracy: 0.4492
# Epoch 2: val_loss improved from 2.25438 to 2.04148, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 177ms/step - loss: 2.0383 - accuracy: 0.4492 - precision_1: 0.7826 - recall_1: 0.0481 - categorical_accuracy: 0.4492 - val_loss: 2.0415 - val_accuracy: 0.4333 - val_precision_1: 0.6087 - val_recall_1: 0.1556 - val_categorical_accuracy: 0.4333 - lr: 1.0000e-04
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 1.8062 - accuracy: 0.6337 - precision_1: 0.9239 - recall_1: 0.2273 - categorical_accuracy: 0.6337
# Epoch 3: val_loss improved from 2.04148 to 1.91471, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 223ms/step - loss: 1.8062 - accuracy: 0.6337 - precision_1: 0.9239 - recall_1: 0.2273 - categorical_accuracy: 0.6337 - val_loss: 1.9147 - val_accuracy: 0.4889 - val_precision_1: 0.6944 - val_recall_1: 0.2778 - val_categorical_accuracy: 0.4889 - lr: 1.0000e-04
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 1.5654 - accuracy: 0.7807 - precision_1: 0.9382 - recall_1: 0.4465 - categorical_accuracy: 0.7807
# Epoch 4: val_loss improved from 1.91471 to 1.78465, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 188ms/step - loss: 1.5654 - accuracy: 0.7807 - precision_1: 0.9382 - recall_1: 0.4465 - categorical_accuracy: 0.7807 - val_loss: 1.7847 - val_accuracy: 0.5667 - val_precision_1: 0.6230 - val_recall_1: 0.4222 - val_categorical_accuracy: 0.5667 - lr: 1.0000e-04
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 1.3730 - accuracy: 0.8102 - precision_1: 0.9185 - recall_1: 0.6631 - categorical_accuracy: 0.8102
# Epoch 5: val_loss improved from 1.78465 to 1.56754, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 177ms/step - loss: 1.3730 - accuracy: 0.8102 - precision_1: 0.9185 - recall_1: 0.6631 - categorical_accuracy: 0.8102 - val_loss: 1.5675 - val_accuracy: 0.6667 - val_precision_1: 0.7361 - val_recall_1: 0.5889 - val_categorical_accuracy: 0.6667 - lr: 1.0000e-04
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 1.2442 - accuracy: 0.8529 - precision_1: 0.9218 - recall_1: 0.7567 - categorical_accuracy: 0.8529
# Epoch 6: val_loss improved from 1.56754 to 1.41156, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 223ms/step - loss: 1.2442 - accuracy: 0.8529 - precision_1: 0.9218 - recall_1: 0.7567 - categorical_accuracy: 0.8529 - val_loss: 1.4116 - val_accuracy: 0.7778 - val_precision_1: 0.8267 - val_recall_1: 0.6889 - val_categorical_accuracy: 0.7778 - lr: 1.0000e-04
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 1.1206 - accuracy: 0.8904 - precision_1: 0.9329 - recall_1: 0.8182 - categorical_accuracy: 0.8904
# Epoch 7: val_loss improved from 1.41156 to 1.33256, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 219ms/step - loss: 1.1206 - accuracy: 0.8904 - precision_1: 0.9329 - recall_1: 0.8182 - categorical_accuracy: 0.8904 - val_loss: 1.3326 - val_accuracy: 0.7889 - val_precision_1: 0.8272 - val_recall_1: 0.7444 - val_categorical_accuracy: 0.7889 - lr: 1.0000e-04
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0721 - accuracy: 0.9091 - precision_1: 0.9292 - recall_1: 0.8770 - categorical_accuracy: 0.9091
# Epoch 8: val_loss improved from 1.33256 to 1.30100, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 179ms/step - loss: 1.0721 - accuracy: 0.9091 - precision_1: 0.9292 - recall_1: 0.8770 - categorical_accuracy: 0.9091 - val_loss: 1.3010 - val_accuracy: 0.8000 - val_precision_1: 0.8625 - val_recall_1: 0.7667 - val_categorical_accuracy: 0.8000 - lr: 1.0000e-04
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 1.0048 - accuracy: 0.9144 - precision_1: 0.9460 - recall_1: 0.8904 - categorical_accuracy: 0.9144
# Epoch 9: val_loss improved from 1.30100 to 1.28842, saving model to ./models/inception.keras
# 38/38 [==============================] - 9s 229ms/step - loss: 1.0048 - accuracy: 0.9144 - precision_1: 0.9460 - recall_1: 0.8904 - categorical_accuracy: 0.9144 - val_loss: 1.2884 - val_accuracy: 0.8111 - val_precision_1: 0.8395 - val_recall_1: 0.7556 - val_categorical_accuracy: 0.8111 - lr: 1.0000e-04
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9714 - accuracy: 0.9278 - precision_1: 0.9466 - recall_1: 0.9011 - categorical_accuracy: 0.9278
# Epoch 10: val_loss improved from 1.28842 to 1.20706, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 181ms/step - loss: 0.9714 - accuracy: 0.9278 - precision_1: 0.9466 - recall_1: 0.9011 - categorical_accuracy: 0.9278 - val_loss: 1.2071 - val_accuracy: 0.8333 - val_precision_1: 0.8675 - val_recall_1: 0.8000 - val_categorical_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 0.9213 - accuracy: 0.9492 - precision_1: 0.9643 - recall_1: 0.9385 - categorical_accuracy: 0.9492
# Epoch 11: val_loss improved from 1.20706 to 1.16610, saving model to ./models/inception.keras
# 38/38 [==============================] - 9s 243ms/step - loss: 0.9213 - accuracy: 0.9492 - precision_1: 0.9643 - recall_1: 0.9385 - categorical_accuracy: 0.9492 - val_loss: 1.1661 - val_accuracy: 0.8111 - val_precision_1: 0.8372 - val_recall_1: 0.8000 - val_categorical_accuracy: 0.8111 - lr: 1.0000e-04
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8689 - accuracy: 0.9626 - precision_1: 0.9701 - recall_1: 0.9545 - categorical_accuracy: 0.9626
# Epoch 12: val_loss improved from 1.16610 to 1.09439, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 179ms/step - loss: 0.8689 - accuracy: 0.9626 - precision_1: 0.9701 - recall_1: 0.9545 - categorical_accuracy: 0.9626 - val_loss: 1.0944 - val_accuracy: 0.8333 - val_precision_1: 0.8721 - val_recall_1: 0.8333 - val_categorical_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8897 - accuracy: 0.9412 - precision_1: 0.9612 - recall_1: 0.9278 - categorical_accuracy: 0.9412
# Epoch 13: val_loss improved from 1.09439 to 1.03931, saving model to ./models/inception.keras
# 38/38 [==============================] - 9s 230ms/step - loss: 0.8897 - accuracy: 0.9412 - precision_1: 0.9612 - recall_1: 0.9278 - categorical_accuracy: 0.9412 - val_loss: 1.0393 - val_accuracy: 0.8778 - val_precision_1: 0.9176 - val_recall_1: 0.8667 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 0.8104 - accuracy: 0.9652 - precision_1: 0.9701 - recall_1: 0.9545 - categorical_accuracy: 0.9652
# Epoch 14: val_loss did not improve from 1.03931
# 38/38 [==============================] - 6s 153ms/step - loss: 0.8104 - accuracy: 0.9652 - precision_1: 0.9701 - recall_1: 0.9545 - categorical_accuracy: 0.9652 - val_loss: 1.0638 - val_accuracy: 0.9000 - val_precision_1: 0.8989 - val_recall_1: 0.8889 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 0.7742 - accuracy: 0.9706 - precision_1: 0.9810 - recall_1: 0.9679 - categorical_accuracy: 0.9706
# Epoch 15: val_loss improved from 1.03931 to 1.01264, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 178ms/step - loss: 0.7742 - accuracy: 0.9706 - precision_1: 0.9810 - recall_1: 0.9679 - categorical_accuracy: 0.9706 - val_loss: 1.0126 - val_accuracy: 0.8889 - val_precision_1: 0.8876 - val_recall_1: 0.8778 - val_categorical_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 0.7952 - accuracy: 0.9679 - precision_1: 0.9781 - recall_1: 0.9572 - categorical_accuracy: 0.9679
# Epoch 16: val_loss did not improve from 1.01264
# 38/38 [==============================] - 8s 201ms/step - loss: 0.7952 - accuracy: 0.9679 - precision_1: 0.9781 - recall_1: 0.9572 - categorical_accuracy: 0.9679 - val_loss: 1.0818 - val_accuracy: 0.8333 - val_precision_1: 0.8409 - val_recall_1: 0.8222 - val_categorical_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 0.7256 - accuracy: 0.9813 - precision_1: 0.9892 - recall_1: 0.9786 - categorical_accuracy: 0.9813
# Epoch 17: val_loss did not improve from 1.01264
# 38/38 [==============================] - 6s 149ms/step - loss: 0.7256 - accuracy: 0.9813 - precision_1: 0.9892 - recall_1: 0.9786 - categorical_accuracy: 0.9813 - val_loss: 1.0403 - val_accuracy: 0.8778 - val_precision_1: 0.8851 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 0.7374 - accuracy: 0.9733 - precision_1: 0.9785 - recall_1: 0.9733 - categorical_accuracy: 0.9733
# Epoch 18: val_loss improved from 1.01264 to 0.99228, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 177ms/step - loss: 0.7374 - accuracy: 0.9733 - precision_1: 0.9785 - recall_1: 0.9733 - categorical_accuracy: 0.9733 - val_loss: 0.9923 - val_accuracy: 0.8556 - val_precision_1: 0.8556 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 0.6897 - accuracy: 0.9920 - precision_1: 0.9920 - recall_1: 0.9893 - categorical_accuracy: 0.9920
# Epoch 19: val_loss did not improve from 0.99228
# 38/38 [==============================] - 7s 190ms/step - loss: 0.6897 - accuracy: 0.9920 - precision_1: 0.9920 - recall_1: 0.9893 - categorical_accuracy: 0.9920 - val_loss: 1.0181 - val_accuracy: 0.8556 - val_precision_1: 0.8556 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 20/100
# 38/38 [==============================] - ETA: 0s - loss: 0.7006 - accuracy: 0.9679 - precision_1: 0.9677 - recall_1: 0.9626 - categorical_accuracy: 0.9679
# Epoch 20: val_loss did not improve from 0.99228
# 38/38 [==============================] - 6s 154ms/step - loss: 0.7006 - accuracy: 0.9679 - precision_1: 0.9677 - recall_1: 0.9626 - categorical_accuracy: 0.9679 - val_loss: 1.0267 - val_accuracy: 0.8444 - val_precision_1: 0.8427 - val_recall_1: 0.8333 - val_categorical_accuracy: 0.8444 - lr: 1.0000e-04
# Epoch 21/100
# 38/38 [==============================] - ETA: 0s - loss: 0.6424 - accuracy: 0.9893 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9893
# Epoch 21: val_loss did not improve from 0.99228
# 38/38 [==============================] - 6s 166ms/step - loss: 0.6424 - accuracy: 0.9893 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9893 - val_loss: 1.0448 - val_accuracy: 0.8556 - val_precision_1: 0.8750 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 22/100
# 38/38 [==============================] - ETA: 0s - loss: 0.6292 - accuracy: 0.9920 - precision_1: 0.9973 - recall_1: 0.9920 - categorical_accuracy: 0.9920
# Epoch 22: val_loss did not improve from 0.99228
# 38/38 [==============================] - 7s 174ms/step - loss: 0.6292 - accuracy: 0.9920 - precision_1: 0.9973 - recall_1: 0.9920 - categorical_accuracy: 0.9920 - val_loss: 1.0206 - val_accuracy: 0.8667 - val_precision_1: 0.8966 - val_recall_1: 0.8667 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 23/100
# 38/38 [==============================] - ETA: 0s - loss: 0.6224 - accuracy: 0.9866 - precision_1: 0.9866 - recall_1: 0.9813 - categorical_accuracy: 0.9866
# Epoch 23: val_loss improved from 0.99228 to 0.94245, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 198ms/step - loss: 0.6224 - accuracy: 0.9866 - precision_1: 0.9866 - recall_1: 0.9813 - categorical_accuracy: 0.9866 - val_loss: 0.9424 - val_accuracy: 0.8889 - val_precision_1: 0.8953 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 24/100
# 38/38 [==============================] - ETA: 0s - loss: 0.6086 - accuracy: 0.9840 - precision_1: 0.9840 - recall_1: 0.9840 - categorical_accuracy: 0.9840
# Epoch 24: val_loss did not improve from 0.94245
# 38/38 [==============================] - 7s 167ms/step - loss: 0.6086 - accuracy: 0.9840 - precision_1: 0.9840 - recall_1: 0.9840 - categorical_accuracy: 0.9840 - val_loss: 1.0580 - val_accuracy: 0.8222 - val_precision_1: 0.8391 - val_recall_1: 0.8111 - val_categorical_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 25/100
# 38/38 [==============================] - ETA: 0s - loss: 0.5986 - accuracy: 0.9789 - precision_1: 0.9815 - recall_1: 0.9763 - categorical_accuracy: 0.9789
# Epoch 25: val_loss improved from 0.94245 to 0.92074, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 194ms/step - loss: 0.5986 - accuracy: 0.9789 - precision_1: 0.9815 - recall_1: 0.9763 - categorical_accuracy: 0.9789 - val_loss: 0.9207 - val_accuracy: 0.8556 - val_precision_1: 0.8621 - val_recall_1: 0.8333 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 26/100
# 38/38 [==============================] - ETA: 0s - loss: 0.5553 - accuracy: 0.9920 - precision_1: 0.9946 - recall_1: 0.9893 - categorical_accuracy: 0.9920
# Epoch 26: val_loss improved from 0.92074 to 0.91838, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 176ms/step - loss: 0.5553 - accuracy: 0.9920 - precision_1: 0.9946 - recall_1: 0.9893 - categorical_accuracy: 0.9920 - val_loss: 0.9184 - val_accuracy: 0.8556 - val_precision_1: 0.8750 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 27/100
# 38/38 [==============================] - ETA: 0s - loss: 0.5722 - accuracy: 0.9840 - precision_1: 0.9865 - recall_1: 0.9786 - categorical_accuracy: 0.9840
# Epoch 27: val_loss improved from 0.91838 to 0.71612, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 218ms/step - loss: 0.5722 - accuracy: 0.9840 - precision_1: 0.9865 - recall_1: 0.9786 - categorical_accuracy: 0.9840 - val_loss: 0.7161 - val_accuracy: 0.8778 - val_precision_1: 0.9186 - val_recall_1: 0.8778 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 28/100
# 38/38 [==============================] - ETA: 0s - loss: 0.5489 - accuracy: 0.9813 - precision_1: 0.9865 - recall_1: 0.9786 - categorical_accuracy: 0.9813
# Epoch 28: val_loss did not improve from 0.71612
# 38/38 [==============================] - 6s 153ms/step - loss: 0.5489 - accuracy: 0.9813 - precision_1: 0.9865 - recall_1: 0.9786 - categorical_accuracy: 0.9813 - val_loss: 0.8247 - val_accuracy: 0.8556 - val_precision_1: 0.8837 - val_recall_1: 0.8444 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 29/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4960 - accuracy: 0.9947 - precision_1: 0.9946 - recall_1: 0.9920 - categorical_accuracy: 0.9947
# Epoch 29: val_loss did not improve from 0.71612
# 38/38 [==============================] - 8s 200ms/step - loss: 0.4960 - accuracy: 0.9947 - precision_1: 0.9946 - recall_1: 0.9920 - categorical_accuracy: 0.9947 - val_loss: 0.8605 - val_accuracy: 0.8222 - val_precision_1: 0.8409 - val_recall_1: 0.8222 - val_categorical_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 30/100
# 38/38 [==============================] - ETA: 0s - loss: 0.5014 - accuracy: 0.9893 - precision_1: 0.9893 - recall_1: 0.9893 - categorical_accuracy: 0.9893
# Epoch 30: val_loss improved from 0.71612 to 0.70844, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 178ms/step - loss: 0.5014 - accuracy: 0.9893 - precision_1: 0.9893 - recall_1: 0.9893 - categorical_accuracy: 0.9893 - val_loss: 0.7084 - val_accuracy: 0.9000 - val_precision_1: 0.9294 - val_recall_1: 0.8778 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 31/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4852 - accuracy: 0.9866 - precision_1: 0.9866 - recall_1: 0.9813 - categorical_accuracy: 0.9866
# Epoch 31: val_loss did not improve from 0.70844
# 38/38 [==============================] - 7s 196ms/step - loss: 0.4852 - accuracy: 0.9866 - precision_1: 0.9866 - recall_1: 0.9813 - categorical_accuracy: 0.9866 - val_loss: 0.8384 - val_accuracy: 0.8667 - val_precision_1: 0.8750 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 32/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4481 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947
# Epoch 32: val_loss improved from 0.70844 to 0.68048, saving model to ./models/inception.keras
# 38/38 [==============================] - 9s 237ms/step - loss: 0.4481 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947 - val_loss: 0.6805 - val_accuracy: 0.8778 - val_precision_1: 0.8876 - val_recall_1: 0.8778 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 33/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4355 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947
# Epoch 33: val_loss improved from 0.68048 to 0.66240, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 177ms/step - loss: 0.4355 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947 - val_loss: 0.6624 - val_accuracy: 0.8667 - val_precision_1: 0.9059 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 34/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4253 - accuracy: 0.9893 - precision_1: 0.9892 - recall_1: 0.9840 - categorical_accuracy: 0.9893
# Epoch 34: val_loss did not improve from 0.66240
# 38/38 [==============================] - 8s 195ms/step - loss: 0.4253 - accuracy: 0.9893 - precision_1: 0.9892 - recall_1: 0.9840 - categorical_accuracy: 0.9893 - val_loss: 0.6701 - val_accuracy: 0.8667 - val_precision_1: 0.8837 - val_recall_1: 0.8444 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 35/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3987 - accuracy: 0.9947 - precision_1: 0.9946 - recall_1: 0.9920 - categorical_accuracy: 0.9947
# Epoch 35: val_loss improved from 0.66240 to 0.66227, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 177ms/step - loss: 0.3987 - accuracy: 0.9947 - precision_1: 0.9946 - recall_1: 0.9920 - categorical_accuracy: 0.9947 - val_loss: 0.6623 - val_accuracy: 0.8444 - val_precision_1: 0.8621 - val_recall_1: 0.8333 - val_categorical_accuracy: 0.8444 - lr: 1.0000e-04
# Epoch 36/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.9840 - precision_1: 0.9866 - recall_1: 0.9840 - categorical_accuracy: 0.9840
# Epoch 36: val_loss improved from 0.66227 to 0.53112, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 178ms/step - loss: 0.4060 - accuracy: 0.9840 - precision_1: 0.9866 - recall_1: 0.9840 - categorical_accuracy: 0.9840 - val_loss: 0.5311 - val_accuracy: 0.8889 - val_precision_1: 0.9195 - val_recall_1: 0.8889 - val_categorical_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 37/100
# 38/38 [==============================] - ETA: 0s - loss: 0.4092 - accuracy: 0.9840 - precision_1: 0.9839 - recall_1: 0.9786 - categorical_accuracy: 0.9840
# Epoch 37: val_loss did not improve from 0.53112
# 38/38 [==============================] - 8s 201ms/step - loss: 0.4092 - accuracy: 0.9840 - precision_1: 0.9839 - recall_1: 0.9786 - categorical_accuracy: 0.9840 - val_loss: 0.7525 - val_accuracy: 0.8222 - val_precision_1: 0.8506 - val_recall_1: 0.8222 - val_categorical_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 38/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3549 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973
# Epoch 38: val_loss did not improve from 0.53112
# 38/38 [==============================] - 6s 153ms/step - loss: 0.3549 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973 - val_loss: 0.6682 - val_accuracy: 0.8667 - val_precision_1: 0.8851 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 39/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3755 - accuracy: 0.9840 - precision_1: 0.9865 - recall_1: 0.9786 - categorical_accuracy: 0.9840
# Epoch 39: val_loss did not improve from 0.53112
# 38/38 [==============================] - 6s 156ms/step - loss: 0.3755 - accuracy: 0.9840 - precision_1: 0.9865 - recall_1: 0.9786 - categorical_accuracy: 0.9840 - val_loss: 0.6998 - val_accuracy: 0.8556 - val_precision_1: 0.8652 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 40/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973
# Epoch 40: val_loss did not improve from 0.53112
# 38/38 [==============================] - 8s 203ms/step - loss: 0.3409 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973 - val_loss: 0.6578 - val_accuracy: 0.8444 - val_precision_1: 0.8837 - val_recall_1: 0.8444 - val_categorical_accuracy: 0.8444 - lr: 1.0000e-04
# Epoch 41/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947
# Epoch 41: val_loss did not improve from 0.53112
# 38/38 [==============================] - 6s 153ms/step - loss: 0.3119 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947 - val_loss: 0.7117 - val_accuracy: 0.8667 - val_precision_1: 0.8636 - val_recall_1: 0.8444 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 42/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.9866 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9866
# Epoch 42: val_loss improved from 0.53112 to 0.52566, saving model to ./models/inception.keras
# 38/38 [==============================] - 9s 240ms/step - loss: 0.3157 - accuracy: 0.9866 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9866 - val_loss: 0.5257 - val_accuracy: 0.8889 - val_precision_1: 0.8889 - val_recall_1: 0.8889 - val_categorical_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 0.3009 - accuracy: 0.9893 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9893
# Epoch 43: val_loss improved from 0.52566 to 0.52234, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 178ms/step - loss: 0.3009 - accuracy: 0.9893 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9893 - val_loss: 0.5223 - val_accuracy: 0.9111 - val_precision_1: 0.9195 - val_recall_1: 0.8889 - val_categorical_accuracy: 0.9111 - lr: 1.0000e-04
# Epoch 44/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2704 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.52234
# 38/38 [==============================] - 6s 151ms/step - loss: 0.2704 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.5554 - val_accuracy: 0.8444 - val_precision_1: 0.8605 - val_recall_1: 0.8222 - val_categorical_accuracy: 0.8444 - lr: 1.0000e-04
# Epoch 45/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0.9866 - precision_1: 0.9866 - recall_1: 0.9813 - categorical_accuracy: 0.9866
# Epoch 45: val_loss improved from 0.52234 to 0.51311, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 190ms/step - loss: 0.2772 - accuracy: 0.9866 - precision_1: 0.9866 - recall_1: 0.9813 - categorical_accuracy: 0.9866 - val_loss: 0.5131 - val_accuracy: 0.9111 - val_precision_1: 0.9286 - val_recall_1: 0.8667 - val_categorical_accuracy: 0.9111 - lr: 1.0000e-04
# Epoch 46/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973
# Epoch 46: val_loss improved from 0.51311 to 0.49576, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 213ms/step - loss: 0.2594 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973 - val_loss: 0.4958 - val_accuracy: 0.8778 - val_precision_1: 0.8953 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 47/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 47: val_loss improved from 0.49576 to 0.44804, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 178ms/step - loss: 0.2405 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.4480 - val_accuracy: 0.9000 - val_precision_1: 0.9205 - val_recall_1: 0.9000 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 48/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.9947 - precision_1: 0.9973 - recall_1: 0.9893 - categorical_accuracy: 0.9947
# Epoch 48: val_loss did not improve from 0.44804
# 38/38 [==============================] - 8s 209ms/step - loss: 0.2443 - accuracy: 0.9947 - precision_1: 0.9973 - recall_1: 0.9893 - categorical_accuracy: 0.9947 - val_loss: 0.5220 - val_accuracy: 0.8778 - val_precision_1: 0.8977 - val_recall_1: 0.8778 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 49/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9893 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9893
# Epoch 49: val_loss did not improve from 0.44804
# 38/38 [==============================] - 6s 150ms/step - loss: 0.2547 - accuracy: 0.9893 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9893 - val_loss: 0.5818 - val_accuracy: 0.8556 - val_precision_1: 0.8750 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 50/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9893 - precision_1: 0.9920 - recall_1: 0.9893 - categorical_accuracy: 0.9893
# Epoch 50: val_loss did not improve from 0.44804
# 38/38 [==============================] - 7s 190ms/step - loss: 0.2372 - accuracy: 0.9893 - precision_1: 0.9920 - recall_1: 0.9893 - categorical_accuracy: 0.9893 - val_loss: 0.5223 - val_accuracy: 0.8778 - val_precision_1: 0.9080 - val_recall_1: 0.8778 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 51/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2047 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973
# Epoch 51: val_loss improved from 0.44804 to 0.43314, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 178ms/step - loss: 0.2047 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973 - val_loss: 0.4331 - val_accuracy: 0.9222 - val_precision_1: 0.9419 - val_recall_1: 0.9000 - val_categorical_accuracy: 0.9222 - lr: 1.0000e-04
# Epoch 52/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2044 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 52: val_loss improved from 0.43314 to 0.42124, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 221ms/step - loss: 0.2044 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.4212 - val_accuracy: 0.9111 - val_precision_1: 0.9205 - val_recall_1: 0.9000 - val_categorical_accuracy: 0.9111 - lr: 1.0000e-04
# Epoch 53/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 53: val_loss did not improve from 0.42124
# 38/38 [==============================] - 6s 152ms/step - loss: 0.1984 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.4431 - val_accuracy: 0.8667 - val_precision_1: 0.8764 - val_recall_1: 0.8667 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 54/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9973
# Epoch 54: val_loss improved from 0.42124 to 0.41967, saving model to ./models/inception.keras
# 38/38 [==============================] - 10s 267ms/step - loss: 0.1993 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9973 - val_loss: 0.4197 - val_accuracy: 0.9000 - val_precision_1: 0.9302 - val_recall_1: 0.8889 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 55/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2092 - accuracy: 0.9920 - precision_1: 0.9946 - recall_1: 0.9786 - categorical_accuracy: 0.9920
# Epoch 55: val_loss improved from 0.41967 to 0.40343, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 225ms/step - loss: 0.2092 - accuracy: 0.9920 - precision_1: 0.9946 - recall_1: 0.9786 - categorical_accuracy: 0.9920 - val_loss: 0.4034 - val_accuracy: 0.9111 - val_precision_1: 0.9205 - val_recall_1: 0.9000 - val_categorical_accuracy: 0.9111 - lr: 1.0000e-04
# Epoch 56/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9920 - precision_1: 0.9919 - recall_1: 0.9840 - categorical_accuracy: 0.9920
# Epoch 56: val_loss did not improve from 0.40343
# 38/38 [==============================] - 6s 152ms/step - loss: 0.1930 - accuracy: 0.9920 - precision_1: 0.9919 - recall_1: 0.9840 - categorical_accuracy: 0.9920 - val_loss: 0.4400 - val_accuracy: 0.9000 - val_precision_1: 0.9080 - val_recall_1: 0.8778 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 57/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9920 - precision_1: 0.9946 - recall_1: 0.9893 - categorical_accuracy: 0.9920
# Epoch 57: val_loss did not improve from 0.40343
# 38/38 [==============================] - 7s 186ms/step - loss: 0.1928 - accuracy: 0.9920 - precision_1: 0.9946 - recall_1: 0.9893 - categorical_accuracy: 0.9920 - val_loss: 0.4664 - val_accuracy: 0.8778 - val_precision_1: 0.8851 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 58/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9866 - precision_1: 0.9866 - recall_1: 0.9840 - categorical_accuracy: 0.9866
# Epoch 58: val_loss improved from 0.40343 to 0.40014, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 185ms/step - loss: 0.1967 - accuracy: 0.9866 - precision_1: 0.9866 - recall_1: 0.9840 - categorical_accuracy: 0.9866 - val_loss: 0.4001 - val_accuracy: 0.9333 - val_precision_1: 0.9310 - val_recall_1: 0.9000 - val_categorical_accuracy: 0.9333 - lr: 1.0000e-04
# Epoch 59/100
# 38/38 [==============================] - ETA: 0s - loss: 0.2010 - accuracy: 0.9813 - precision_1: 0.9892 - recall_1: 0.9759 - categorical_accuracy: 0.9813
# Epoch 59: val_loss improved from 0.40014 to 0.38789, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 221ms/step - loss: 0.2010 - accuracy: 0.9813 - precision_1: 0.9892 - recall_1: 0.9759 - categorical_accuracy: 0.9813 - val_loss: 0.3879 - val_accuracy: 0.9000 - val_precision_1: 0.9205 - val_recall_1: 0.9000 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 60/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947
# Epoch 60: val_loss improved from 0.38789 to 0.35060, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 180ms/step - loss: 0.1731 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947 - val_loss: 0.3506 - val_accuracy: 0.9222 - val_precision_1: 0.9326 - val_recall_1: 0.9222 - val_categorical_accuracy: 0.9222 - lr: 1.0000e-04
# Epoch 61/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9947 - precision_1: 0.9973 - recall_1: 0.9920 - categorical_accuracy: 0.9947
# Epoch 61: val_loss improved from 0.35060 to 0.34801, saving model to ./models/inception.keras
# 38/38 [==============================] - 9s 229ms/step - loss: 0.1608 - accuracy: 0.9947 - precision_1: 0.9973 - recall_1: 0.9920 - categorical_accuracy: 0.9947 - val_loss: 0.3480 - val_accuracy: 0.9111 - val_precision_1: 0.9294 - val_recall_1: 0.8778 - val_categorical_accuracy: 0.9111 - lr: 1.0000e-04
# Epoch 62/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1664 - accuracy: 0.9866 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9866
# Epoch 62: val_loss improved from 0.34801 to 0.33994, saving model to ./models/inception.keras
# 38/38 [==============================] - 7s 192ms/step - loss: 0.1664 - accuracy: 0.9866 - precision_1: 0.9893 - recall_1: 0.9866 - categorical_accuracy: 0.9866 - val_loss: 0.3399 - val_accuracy: 0.9000 - val_precision_1: 0.9101 - val_recall_1: 0.9000 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 63/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9947 - precision_1: 0.9973 - recall_1: 0.9920 - categorical_accuracy: 0.9947
# Epoch 63: val_loss did not improve from 0.33994
# 38/38 [==============================] - 8s 199ms/step - loss: 0.1609 - accuracy: 0.9947 - precision_1: 0.9973 - recall_1: 0.9920 - categorical_accuracy: 0.9947 - val_loss: 0.5168 - val_accuracy: 0.8111 - val_precision_1: 0.8182 - val_recall_1: 0.8000 - val_categorical_accuracy: 0.8111 - lr: 1.0000e-04
# Epoch 64/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 64: val_loss did not improve from 0.33994
# 38/38 [==============================] - 6s 153ms/step - loss: 0.1458 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.3815 - val_accuracy: 0.8667 - val_precision_1: 0.8636 - val_recall_1: 0.8444 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 65/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9973
# Epoch 65: val_loss did not improve from 0.33994
# 38/38 [==============================] - 8s 200ms/step - loss: 0.1495 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9973 - val_loss: 0.3862 - val_accuracy: 0.8667 - val_precision_1: 0.8636 - val_recall_1: 0.8444 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 66/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 0.9973 - categorical_accuracy: 1.0000
# Epoch 66: val_loss did not improve from 0.33994
# 38/38 [==============================] - 6s 151ms/step - loss: 0.1312 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 0.9973 - categorical_accuracy: 1.0000 - val_loss: 0.4263 - val_accuracy: 0.8333 - val_precision_1: 0.8427 - val_recall_1: 0.8333 - val_categorical_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 67/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947
# Epoch 67: val_loss did not improve from 0.33994
# 38/38 [==============================] - 7s 194ms/step - loss: 0.1444 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947 - val_loss: 0.4102 - val_accuracy: 0.8444 - val_precision_1: 0.8690 - val_recall_1: 0.8111 - val_categorical_accuracy: 0.8444 - lr: 1.0000e-04
# Epoch 68/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947
# Epoch 68: val_loss did not improve from 0.33994
# 38/38 [==============================] - 6s 155ms/step - loss: 0.1384 - accuracy: 0.9947 - precision_1: 0.9947 - recall_1: 0.9947 - categorical_accuracy: 0.9947 - val_loss: 0.4232 - val_accuracy: 0.8444 - val_precision_1: 0.8824 - val_recall_1: 0.8333 - val_categorical_accuracy: 0.8444 - lr: 1.0000e-04
# Epoch 69/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9920 - precision_1: 0.9946 - recall_1: 0.9866 - categorical_accuracy: 0.9920
# Epoch 69: val_loss improved from 0.33994 to 0.29648, saving model to ./models/inception.keras
# 38/38 [==============================] - 8s 216ms/step - loss: 0.1377 - accuracy: 0.9920 - precision_1: 0.9946 - recall_1: 0.9866 - categorical_accuracy: 0.9920 - val_loss: 0.2965 - val_accuracy: 0.9333 - val_precision_1: 0.9419 - val_recall_1: 0.9000 - val_categorical_accuracy: 0.9333 - lr: 1.0000e-04
# Epoch 70/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 0.9920 - categorical_accuracy: 1.0000
# Epoch 70: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 153ms/step - loss: 0.1334 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 0.9920 - categorical_accuracy: 1.0000 - val_loss: 0.4089 - val_accuracy: 0.8556 - val_precision_1: 0.8556 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 71/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9947 - precision_1: 0.9946 - recall_1: 0.9893 - categorical_accuracy: 0.9947
# Epoch 71: val_loss did not improve from 0.29648
# 38/38 [==============================] - 7s 187ms/step - loss: 0.1457 - accuracy: 0.9947 - precision_1: 0.9946 - recall_1: 0.9893 - categorical_accuracy: 0.9947 - val_loss: 0.4377 - val_accuracy: 0.8556 - val_precision_1: 0.8539 - val_recall_1: 0.8444 - val_categorical_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 72/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 154ms/step - loss: 0.1232 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.4048 - val_accuracy: 0.8667 - val_precision_1: 0.8750 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 73/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9947 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9947
# Epoch 73: val_loss did not improve from 0.29648
# 38/38 [==============================] - 8s 204ms/step - loss: 0.1306 - accuracy: 0.9947 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9947 - val_loss: 0.3200 - val_accuracy: 0.9111 - val_precision_1: 0.9310 - val_recall_1: 0.9000 - val_categorical_accuracy: 0.9111 - lr: 1.0000e-04
# Epoch 74/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 74: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 153ms/step - loss: 0.1262 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.3596 - val_accuracy: 0.9000 - val_precision_1: 0.9091 - val_recall_1: 0.8889 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 75/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9947 - precision_1: 0.9946 - recall_1: 0.9920 - categorical_accuracy: 0.9947
# Epoch 75: val_loss did not improve from 0.29648
# 38/38 [==============================] - 8s 201ms/step - loss: 0.1255 - accuracy: 0.9947 - precision_1: 0.9946 - recall_1: 0.9920 - categorical_accuracy: 0.9947 - val_loss: 0.4811 - val_accuracy: 0.8333 - val_precision_1: 0.8391 - val_recall_1: 0.8111 - val_categorical_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 76/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1223 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 76: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 154ms/step - loss: 0.1223 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.4019 - val_accuracy: 0.8778 - val_precision_1: 0.8750 - val_recall_1: 0.8556 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 77/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 77: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 164ms/step - loss: 0.1129 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.3638 - val_accuracy: 0.8778 - val_precision_1: 0.8778 - val_recall_1: 0.8778 - val_categorical_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 78/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1719 - accuracy: 0.9679 - precision_1: 0.9705 - recall_1: 0.9679 - categorical_accuracy: 0.9679
# Epoch 78: val_loss did not improve from 0.29648
# 38/38 [==============================] - 8s 201ms/step - loss: 0.1719 - accuracy: 0.9679 - precision_1: 0.9705 - recall_1: 0.9679 - categorical_accuracy: 0.9679 - val_loss: 0.5998 - val_accuracy: 0.8000 - val_precision_1: 0.8182 - val_recall_1: 0.8000 - val_categorical_accuracy: 0.8000 - lr: 1.0000e-04
# Epoch 79/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.9813 - precision_1: 0.9839 - recall_1: 0.9813 - categorical_accuracy: 0.9813
# Epoch 79: val_loss did not improve from 0.29648
# 38/38 [==============================] - 7s 175ms/step - loss: 0.1699 - accuracy: 0.9813 - precision_1: 0.9839 - recall_1: 0.9813 - categorical_accuracy: 0.9813 - val_loss: 0.5392 - val_accuracy: 0.8222 - val_precision_1: 0.8315 - val_recall_1: 0.8222 - val_categorical_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 80/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9813 - precision_1: 0.9892 - recall_1: 0.9786 - categorical_accuracy: 0.9813
# Epoch 80: val_loss did not improve from 0.29648
# 38/38 [==============================] - 9s 226ms/step - loss: 0.1661 - accuracy: 0.9813 - precision_1: 0.9892 - recall_1: 0.9786 - categorical_accuracy: 0.9813 - val_loss: 0.4860 - val_accuracy: 0.8111 - val_precision_1: 0.8391 - val_recall_1: 0.8111 - val_categorical_accuracy: 0.8111 - lr: 3.0000e-05
# Epoch 81/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9973
# Epoch 81: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 154ms/step - loss: 0.1201 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9973 - val_loss: 0.4270 - val_accuracy: 0.8556 - val_precision_1: 0.8605 - val_recall_1: 0.8222 - val_categorical_accuracy: 0.8556 - lr: 3.0000e-05
# Epoch 82/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9920 - precision_1: 0.9920 - recall_1: 0.9893 - categorical_accuracy: 0.9920
# Epoch 82: val_loss did not improve from 0.29648
# 38/38 [==============================] - 8s 203ms/step - loss: 0.1363 - accuracy: 0.9920 - precision_1: 0.9920 - recall_1: 0.9893 - categorical_accuracy: 0.9920 - val_loss: 0.4589 - val_accuracy: 0.8333 - val_precision_1: 0.8605 - val_recall_1: 0.8222 - val_categorical_accuracy: 0.8333 - lr: 3.0000e-05
# Epoch 83/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973
# Epoch 83: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 153ms/step - loss: 0.1150 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973 - val_loss: 0.4811 - val_accuracy: 0.8444 - val_precision_1: 0.8409 - val_recall_1: 0.8222 - val_categorical_accuracy: 0.8444 - lr: 3.0000e-05
# Epoch 84/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9973 - precision_1: 1.0000 - recall_1: 0.9973 - categorical_accuracy: 0.9973
# Epoch 84: val_loss did not improve from 0.29648
# 38/38 [==============================] - 8s 200ms/step - loss: 0.1065 - accuracy: 0.9973 - precision_1: 1.0000 - recall_1: 0.9973 - categorical_accuracy: 0.9973 - val_loss: 0.4155 - val_accuracy: 0.8444 - val_precision_1: 0.8523 - val_recall_1: 0.8333 - val_categorical_accuracy: 0.8444 - lr: 3.0000e-05
# Epoch 85/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9973 - precision_1: 1.0000 - recall_1: 0.9973 - categorical_accuracy: 0.9973
# Epoch 85: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 151ms/step - loss: 0.1144 - accuracy: 0.9973 - precision_1: 1.0000 - recall_1: 0.9973 - categorical_accuracy: 0.9973 - val_loss: 0.3845 - val_accuracy: 0.8889 - val_precision_1: 0.8864 - val_recall_1: 0.8667 - val_categorical_accuracy: 0.8889 - lr: 3.0000e-05
# Epoch 86/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 0.9973 - categorical_accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.29648
# 38/38 [==============================] - 8s 198ms/step - loss: 0.1205 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 0.9973 - categorical_accuracy: 1.0000 - val_loss: 0.4071 - val_accuracy: 0.8667 - val_precision_1: 0.8605 - val_recall_1: 0.8222 - val_categorical_accuracy: 0.8667 - lr: 3.0000e-05
# Epoch 87/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0973 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000
# Epoch 87: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0973 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - categorical_accuracy: 1.0000 - val_loss: 0.4189 - val_accuracy: 0.8556 - val_precision_1: 0.8736 - val_recall_1: 0.8444 - val_categorical_accuracy: 0.8556 - lr: 3.0000e-05
# Epoch 88/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9973
# Epoch 88: val_loss did not improve from 0.29648
# 38/38 [==============================] - 8s 202ms/step - loss: 0.1080 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9947 - categorical_accuracy: 0.9973 - val_loss: 0.3694 - val_accuracy: 0.8889 - val_precision_1: 0.8966 - val_recall_1: 0.8667 - val_categorical_accuracy: 0.8889 - lr: 3.0000e-05
# Epoch 89/100
# 38/38 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973
# Epoch 89: val_loss did not improve from 0.29648
# 38/38 [==============================] - 6s 152ms/step - loss: 0.1088 - accuracy: 0.9973 - precision_1: 0.9973 - recall_1: 0.9973 - categorical_accuracy: 0.9973 - val_loss: 0.3443 - val_accuracy: 0.8889 - val_precision_1: 0.8837 - val_recall_1: 0.8444 - val_categorical_accuracy: 0.8889 - lr: 3.0000e-05
# Epoch 89: early stopping

# %% [markdown]
# # Testing the Model

# %%
# Learning curve
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation','Loss', 'Value Loss'], loc='upper left')
plt.show()

# %%
# Validate the model with test data

model = keras.models.load_model(model_file)
model.evaluate(test_generator)


# Predict and Display image using matplotlib
# plt.figure(figsize=(20, 20))
# for i in range(9):
#     plt.subplot(3, 3, i + 1)
#     for X_batch, Y_batch in test_generator:
#         image = X_batch[0]
#         # Print Class
#         plt.title("Predicted: " + classes[predictions[i]] + "\nActual: " + classes[np.argmax(Y_batch[i])])

#         plt.imshow(image)
#         break
# Out:
# 10/10 [==============================] - 5s 49ms/step - loss: 0.3165 - accuracy: 0.9271 - precision_1: 0.9348 - recall_1: 0.8958 - categorical_accuracy: 0.9271
# [0.31654390692710876,
#  0.9270833134651184,
#  0.9347826242446899,
#  0.8958333134651184,
#  0.9270833134651184]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

# Assuming 'classes' contains the class labels
classes = ['meningioma', 'pituitary', 'glioma', 'notumor']

def calculate_metrics(y_true, y_pred):
    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Plot the Confusion Matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Values')
    plt.ylabel('True Values')
    plt.show()

    # Normalize the confusion matrix
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    # Plot the normalized confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Values')
    plt.ylabel('True Values')
    plt.title('Normalized Confusion Matrix')
    plt.show()

    # Calculate metrics for each class and average them
    dsc = np.mean([2.0 * cm[i, i] / (np.sum(cm[i, :]) + np.sum(cm[:, i])) for i in range(cm.shape[0])])
    sensitivity = np.mean([cm[i, i] / np.sum(cm[i, :]) for i in range(cm.shape[0])])
    specificity = np.mean([np.sum(np.delete(np.delete(cm, j, 0), j, 1)) / np.sum(np.delete(cm, j, 0)) for j in range(cm.shape[0])])

    # Accuracy
    accuracy = accuracy_score(y_true, y_pred)

    return dsc, sensitivity, specificity, accuracy

# Assuming 'model' is your trained model and 'test_generator' is your test data generator
predictions_2 = model.predict(test_generator)
predictions_2 = np.argmax(predictions_2, axis=1)

# Assuming 'test_generator.classes' contains the true labels
y_true = test_generator.classes
y_pred = predictions_2

dsc, sensitivity, specificity, accuracy = calculate_metrics(y_true, y_pred)
print(f"DSC: {dsc}, Sensitivity: {sensitivity}, Specificity: {specificity}, Accuracy: {accuracy}")
# Out:
# 10/10 [==============================] - 0s 43ms/step
# DSC: 0.9272023809523811, Sensitivity: 0.9270833333333334, Specificity: 0.9756944444444444, Accuracy: 0.9270833333333334

# %% [markdown]
# # Model Visualisation (Evaluation)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

classes = ['meningioma', 'pituitary', 'glioma', 'notumor']

def calculate_metrics(y_true, y_pred):
    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Plot the Confusion Matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Values')
    plt.ylabel('True Values')
    plt.show()

    # Normalize the confusion matrix
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    # Plot the normalized confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted Values')
    plt.ylabel('True Values')
    plt.title('Normalized Confusion Matrix')
    plt.show()

    # Calculate metrics for each class and average them
    dsc = np.mean([2.0 * cm[i, i] / (np.sum(cm[i, :]) + np.sum(cm[:, i])) for i in range(cm.shape[0])])
    sensitivity = np.mean([cm[i, i] / np.sum(cm[i, :]) for i in range(cm.shape[0])])
    specificity = np.mean([np.sum(np.delete(np.delete(cm, j, 0), j, 1)) / np.sum(np.delete(cm, j, 0)) for j in range(cm.shape[0])])

    # Accuracy
    accuracy = accuracy_score(y_true, y_pred)

    return dsc, sensitivity, specificity, accuracy

# Predict the output
predictions_prob = model.predict(test_generator)
predictions = np.argmax(predictions_prob, axis=1)

dsc, sensitivity, specificity, accuracy = calculate_metrics(test_generator.classes, predictions)
print(f"DSC: {dsc}, Sensitivity: {sensitivity}, Specificity: {specificity}, Accuracy: {accuracy}")
# Out:
# 10/10 [==============================] - 1s 60ms/step
# DSC: 0.9272023809523811, Sensitivity: 0.9270833333333334, Specificity: 0.9756944444444444, Accuracy: 0.9270833333333334

# %%
from sklearn.metrics import roc_curve, auc, classification_report
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import numpy as np

# Binarize the output
lb = LabelBinarizer()
y_test = lb.fit_transform(test_generator.classes)
y_pred = lb.transform(predictions)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(classes)):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], predictions_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure()
for i, class_name in enumerate(classes):
    plt.plot(fpr[i], tpr[i],
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(class_name, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# Print classification report
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#   meningioma       0.96      0.96      0.96        24
#    pituitary       0.84      0.88      0.86        24
#       glioma       0.92      1.00      0.96        24
#      notumor       1.00      0.88      0.93        24
#
#    micro avg       0.93      0.93      0.93        96
#    macro avg       0.93      0.93      0.93        96
# weighted avg       0.93      0.93      0.93        96
#  samples avg       0.93      0.93      0.93        96
